# %% [markdown]
# # ES18
# ## Noemi Baruffolo 5^AROB
# ### Netflix

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("./ver_19-12-24/Netflix-Dataset-Latest-2021.csv")
data.head()
# Out:
#               Title                                   Genre  \
# 0  Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1             Joker                  Crime, Drama, Thriller
# 2                 I      Action, Adventure, Fantasy, Sci-Fi
# 3  Harrys Daughters      Adventure, Drama, Fantasy, Mystery
# 4        The Closet                                  Comedy
#
#                                                 Tags          Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...   Swedish, Spanish
# 1  Dark Comedies,Crime Comedies,Dramas,Comedies,C...            English
# 2                              Dramas,Swedish Movies  English, Sanskrit
# 3                              Dramas,Swedish Movies            English
# 4              Korean Movies,Horror Movies,Mysteries             French
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               3.5
# 2           Movie               2.8
# ...

# %% [markdown]
# ### Terminologia
# La variabile `data` è un oggetto di tipo **DataFrame**
#
# i DataFrame memorizzano dati in forma tabulare
#
# Accesso ad una colonna:

# %%
col = data["IMDb Score"]
col
# Out:
# 0       7.9
# 1       8.4
# 2       6.5
# 3       8.1
# 4       7.0
#        ...
# 2150    6.8
# 2151    6.8
# 2152    6.8
# 2153    4.9
# 2154    5.3
# Name: IMDb Score, Length: 2155, dtype: float64

# %% [markdown]
# La variabile `col` è un oggetto **Series**
#
# Accesso a più colonne:

# %%
cols = data[["Title", "Director"]] #SELECT Title, Director FROM data
cols
# Out:
#                                          Title             Director
# 0                             Lets Fight Ghost      Tomas Alfredson
# 1                                        Joker        Todd Phillips
# 2                                            I         George Lucas
# 3                             Harrys Daughters          David Yates
# 4                                   The Closet        Francis Veber
# ...                                        ...                  ...
# 2150                            50 First Dates          Peter Segal
# 2151                                        21       Robert Luketic
# 2152                                One Chance        David Frankel
# 2153  The Twilight Saga: Breaking Dawn: Part 1          Bill Condon
# 2154                         One for the Money  Julie Anne Robinson
#
# [2155 rows x 2 columns]

# %%
data.index #indice colonna numerica di sinistra
# Out:
# RangeIndex(start=0, stop=2155, step=1)

# %% [markdown]
# ## Caratteristiche del DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  2155 non-null   object
#  1   Genre                  2155 non-null   object
#  2   Tags                   2155 non-null   object
#  3   Languages              2155 non-null   object
#  4   Series or Movie        2155 non-null   object
#  5   Hidden Gem Score       2155 non-null   float64
#  6   Country Availability   2155 non-null   object
#  7   Runtime                2155 non-null   object
#  8   Director               2155 non-null   object
#  9   Writer                 2155 non-null   object
#  10  Actors                 2155 non-null   object
#  11  View Rating            2155 non-null   object
#  12  IMDb Score             2155 non-null   float64
#  13  Rotten Tomatoes Score  2155 non-null   float64
# ...

# %%
data.describe() #colonne numeriche, poi cose statistiche ecc
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       2155.000000  2155.000000            2155.000000       2155.000000
# mean           3.396659     6.788538              65.759165         60.961021
# std            1.090777     0.908366              25.199188         16.927377
# min            0.600000     2.200000               0.000000          6.000000
# 25%            2.700000     6.300000              49.000000         50.000000
# 50%            3.500000     6.900000              72.000000         62.000000
# 75%            4.000000     7.400000              86.000000         73.000000
# max            8.700000     9.300000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For     Boxoffice    IMDb Votes
# count      2155.000000           2155.000000  2.155000e+03  2.155000e+03
# mean         13.547564             27.378654  6.950284e+07  1.917973e+05
# ...

# %% [markdown]
# Un esempio di query sul dataset: selezionare tutti i film/serie con IMDb Score > 9

# %%
#SELECT * FROM data WHERE 'IMDb Score' > 9
data[data["IMDb Score"] > 9]
# Out:
#                          Title         Genre  \
# 1757  The Shawshank Redemption         Drama
# 1808             The Godfather  Crime, Drama
#
#                                                    Tags  \
# 1757  Dramas,20th Century Period Pieces,Dramas based...
# 1808  Dramas,Gangster Films,Classic Films,Dramas bas...
#
#                     Languages Series or Movie  Hidden Gem Score  \
# 1757                  English           Movie               4.4
# 1808  English, Italian, Latin           Movie               4.8
#
#                                    Country Availability  Runtime  \
# 1757  France,Portugal,Belgium,Switzerland,Japan,Spai...  > 2 hrs
# 1808  Romania,Hungary,Hong Kong,Canada,Thailand,Belg...  > 2 hrs
#
#                   Director                            Writer  ...  \
# 1757        Frank Darabont      Frank Darabont, Stephen King  ...
# 1808  Francis Ford Coppola  Mario Puzo, Francis Ford Coppola  ...
#
# ...

# %%
#SELECT 'TMDb Trailer' FROM data WHERE 'IMDb Score' > 9
data[data["IMDb Score"] > 9]["TMDb Trailer"]
# Out:
# 1757    https://www.youtube.com/watch?v=K_tLp7T6U1c
# 1808    https://www.youtube.com/watch?v=1x0GpEZnwa8
# Name: TMDb Trailer, dtype: object

# %%
data["Genre"].unique() #tutti i generi possibili
# Out:
# array(['Crime, Drama, Fantasy, Horror, Romance', 'Crime, Drama, Thriller',
#        'Action, Adventure, Fantasy, Sci-Fi',
#        'Adventure, Drama, Fantasy, Mystery', 'Comedy', 'Comedy, Romance',
#        'Drama', 'Adventure, Drama', 'Adventure, Drama, Mystery',
#        'Crime, Drama, Mystery, Thriller',
#        'Action, Comedy, Crime, Thriller',
#        'Action, Comedy, Crime, Sci-Fi, Thriller',
#        'Crime, Drama, Horror, Thriller',
#        'Action, Adventure, Comedy, Sci-Fi', 'Drama, Mystery, Thriller',
#        'Drama, Mystery', 'Drama, Thriller, Western',
#        'Biography, Crime, Drama', 'Documentary, Action, Crime, Drama',
#        'Comedy, Drama, Family, Romance', 'Biography, Drama',
#        'Adventure, Drama, Horror, Mystery, Sci-Fi, Thriller',
#        'Biography, Drama, Romance', 'Comedy, Drama',
#        'Comedy, Drama, Music, Romance', 'Documentary, Biography, Comedy',
#        'Comedy, Family', 'Biography, Drama, Family, Music',
# ...

# %%
data["Series or Movie"].unique()
# Out:
# array(['Series', 'Movie'], dtype=object)

# %%
# per prendere tutte le serie che hanno il punteggio maggiore di 8
data2 = data[(data["Series or Movie"] == "Series") & (data["IMDb Score"] > 8)]
data2
# Out:
#                                 Title                                Genre  \
# 86                          Spotlight              Biography, Crime, Drama
# 88                             Aliens  Action, Adventure, Sci-Fi, Thriller
# 1203  Monty Pythons Fliegender Zirkus           Adventure, Comedy, Fantasy
#
#                                                    Tags  \
# 86                             TV Comedies,Kids&#39; TV
# 88    Alien Sci-Fi,Comedy Programmes,British Program...
# 1203          TV Comedies,TV Shows,German TV Programmes
#
#                    Languages Series or Movie  Hidden Gem Score  \
# 86                   English          Series               4.5
# 88                   English          Series               4.4
# 1203  English, French, Latin          Series               4.5
#
#                                    Country Availability       Runtime  \
# 86                                  Switzerland,Germany  < 30 minutes
# ...

# %%
data2.to_csv("./prova.csv")

# %%
data2.to_dict() #crea un dizionario
# Out:
# {'Title': {86: 'Spotlight',
#   88: 'Aliens',
#   1203: 'Monty Pythons Fliegender Zirkus'},
#  'Genre': {86: 'Biography, Crime, Drama',
#   88: 'Action, Adventure, Sci-Fi, Thriller',
#   1203: 'Adventure, Comedy, Fantasy'},
#  'Tags': {86: 'TV Comedies,Kids&#39; TV',
#   88: 'Alien Sci-Fi,Comedy Programmes,British Programmes,TV Thrillers,Sci-Fi TV',
#   1203: 'TV Comedies,TV Shows,German TV Programmes'},
#  'Languages': {86: 'English', 88: 'English', 1203: 'English, French, Latin'},
#  'Series or Movie': {86: 'Series', 88: 'Series', 1203: 'Series'},
#  'Hidden Gem Score': {86: 4.5, 88: 4.4, 1203: 4.5},
#  'Country Availability': {86: 'Switzerland,Germany',
#   88: 'United Kingdom',
#   1203: 'Australia,Singapore,Russia,India,Lithuania,United Kingdom,Canada,Romania,South Africa,Thailand,Hungary,Czech Republic,United States,Greece,Slovakia,Malaysia,Iceland,Israel'},
#  'Runtime': {86: '< 30 minutes', 88: '< 30 minutes', 1203: '< 30 minutes'},
#  'Director': {86: 'Tom McCarthy',
# ...

# %%
data2.clipborad() # un nome simile, comunque fa una copia, se poi sotto fai ctrl +v incolli tutto il coso copiato
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3296\1618515647.py in ?()
# ----> 1 data2.clipborad() # un nome simile, comunque fa una copia, se poi sotto fai ctrl +v incolli tutto il coso copiato
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'clipborad'
