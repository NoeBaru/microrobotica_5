# %% [markdown]
# # Es30
# ## Noemi Baruffolo 5^AROB
# ### pag.191 es.3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("csv/SPX.csv", parse_dates=["Date"])
#data_sp["Date"] = pd.to_datetime(data_sp["Date"], errors = "coerce")
data["Days_Since_Start"] = (data_sp["Date"] - pd.Timestamp("1927-12-30")).dt.days

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23323 entries, 0 to 23322
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              23323 non-null  datetime64[ns]
#  1   Open              23323 non-null  float64
#  2   High              23323 non-null  float64
#  3   Low               23323 non-null  float64
#  4   Close             23323 non-null  float64
#  5   Adj Close         23323 non-null  float64
#  6   Volume            23323 non-null  int64
#  7   Days_Since_Start  23323 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 1.4 MB

# %%
x = data["Days_Since_Start"].values.reshape(-1, 1)
y = data_sp["Adj Close"].values

# %% [markdown]
# ### Divisione in train e test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42) #si poteva evitare

# %% [markdown]
# ### Scelta del modello

# %%
model = LinearRegression(fit_intercept = True)

# %% [markdown]
# ### Addestramento del modello

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.score(x.reshape(-1, 1), y)
# Out:
# 0.6354133863281323

# %%
y_pred1 = model.coef_[0] * x + model.intercept_
# oppure uso y_pred1 = model.predict(x)

# %% [markdown]
# ### Regressione con target logaritmo dei valori dell'indice

# %%
y_log = np.log(y)
model2 = LinearRegression()
model2.fit(x, y_log)
y_pred2 = np.exp(model2.predict(x)) 
model2.score(x, y_log)
# Out:
# 0.9580875200949963

# %%
r2_model1 = r2_score(y, y_pred1)
r2_model2 = r2_score(y, y_pred2)

# %%
r2_model2
# Out:
# 0.9337994343509716

# %% [markdown]
# ### Analisi grafica

# %%
fig, ax = plt.subplots(figsize = (12, 6))
ax.plot(data_sp["Date"], y, label="Dati Reali", color="blue", alpha=0.6)
ax.plot(data_sp["Date"], y_pred1, label=f"Regressione Lineare ($R^2$={model.score(x, y)})", color="red")
ax.plot(data_sp["Date"], y_pred2, label=f"Regressione Lineare logaritmo del target($R^2$={model2.score(x, y_log)})", color="green")
ax.set_xlabel("Anno")
ax.set_ylabel("S&P 500 Close")
ax.set_title("Confronto tra Regressioni Lineari")
ax.legend()
ax.grid()
plt.show()
