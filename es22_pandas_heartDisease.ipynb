# %% [markdown]
# # ES22
# ## Noemi Baruffolo 5^AROB
# ### pandas heart disesase

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./csv/heart_disease.csv')
data.head()
# Out:
#     Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family_Heart_Disease Diabetes                     BMI High_Blood_Pressure  \
# 0                  Yes       No  24.991.591.091.690.300                 Yes
# 1                  Yes      Yes     252.217.985.244.363                  No
# 2                   No       No   2.985.544.714.237.160                  No
# 3                  Yes       No  24.130.476.882.852.400                 Yes
# 4                  Yes      Yes   2.048.628.889.057.510                 Yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood_Pressure        9981 non-null   float64
#  3   Cholesterol_Level     9970 non-null   float64
#  4   Exercise_Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family_Heart_Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   object
#  9   High_Blood_Pressure   9974 non-null   object
#  10  Low_HDL_Cholesterol   9975 non-null   object
#  11  High_LDL_Cholesterol  9974 non-null   object
#  12  Alcohol_Consumption   7414 non-null   object
#  13  Stress_Level          9978 non-null   object
#  14  Sleep_Hours           9975 non-null   object
# ...

# %%
# i dati relativi ai fumatori
fumatoriMaschi = data["Smoking"]
fumatoriMaschi
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 9995    Yes
# 9996     No
# 9997    Yes
# 9998    Yes
# 9999    Yes
# Name: Smoking, Length: 10000, dtype: object

# %%
# i dati relativi all'età e pressione delle donne che soffrono di diabete
donneDiabetihe = data[(data["Diabetes"] == "Yes") & (data["Gender"] == "Female")]
etaDonneDiabetihe = data["Age"]
etaDonneDiabetihe
# Out:
# 0       56.0
# 1       69.0
# 2       46.0
# 3       32.0
# 4       60.0
#         ...
# 9995    25.0
# 9996    38.0
# 9997    73.0
# 9998    23.0
# 9999    38.0
# Name: Age, Length: 10000, dtype: float64

# %%
pressioneDonneDiabetiche = data["Blood_Pressure"]
pressioneDonneDiabetiche
# Out:
# 0       153.0
# 1       146.0
# 2       126.0
# 3       122.0
# 4       166.0
#         ...
# 9995    136.0
# 9996    172.0
# 9997    152.0
# 9998    142.0
# 9999    128.0
# Name: Blood_Pressure, Length: 10000, dtype: float64

# %%
# i dati relativi agli uomini di età compresa tra i 18 e i 35 anni
uominiGiovani = data[(data["Age"] >= 18) & (data["Age"] <= 35) & (data["Gender"] == "Male")]
uominiGiovani
# Out:
#        Age Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 5     25.0   Male           152.0              257.0             Low     Yes
# 44    33.0   Male           171.0              287.0          Medium      No
# 60    26.0   Male           153.0              298.0            High     Yes
# 62    35.0   Male           165.0              202.0          Medium      No
# 72    19.0   Male           121.0              182.0             Low      No
# ...    ...    ...             ...                ...             ...     ...
# 9951  25.0   Male           177.0              221.0          Medium      No
# 9971  24.0   Male           143.0              276.0             Low      No
# 9986  23.0   Male           147.0              292.0             Low      No
# 9987  34.0   Male           126.0              166.0          Medium      No
# 9998  23.0   Male           142.0              299.0             Low     Yes
#
# ...

# %%
#il numero totale di fumatori
totFumatori = data["Smoking"] == "Yes"
totFumatori
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9995     True
# 9996    False
# 9997     True
# 9998     True
# 9999     True
# Name: Smoking, Length: 10000, dtype: bool

# %%
#il numero di fumatori raggruppato per genere
data[data["Smoking"]== "Yes"]["Gender"].value_counts()
# Out:
# Gender
# Female    2575
# Male      2538
# Name: count, dtype: int64

# %%
#il numero di Heart_Disease_Status (YES) raggruppato per genere e fumatori (yes/no)
data["Gender", "Smoking", [["Heart_Disease_Status"] == "Yes"]].groupby("Gender", "Smoking").value_count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '('Gender', 'Smoking', [False])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[88], line 2
#       1 #il numero di Heart_Disease_Status (YES) raggruppato per genere e fumatori (yes/no)
# ----> 2 data["Gender", "Smoking", [["Heart_Disease_Status"] == "Yes"]].groupby("Gender", "Smoking").value_count()
#
# ...

# %%
#il numero medio di ore dormite per genere
data[["Gender", "Sleep_Hours"]].groupby("Gender").mean()

# %% [markdown]
# Rappresentare su un grafico a barre la distribuzione dei fumatori maschi per fascia d’età ( 18-30 / 30-45/ 45-60 / 60-80 / 80 e oltre).
# Specificare nome degli assi, titolo e dimensione  del grafico, colore

# %%
#filtro per genere maschile e fumatori
maleSmokers = data[(data['Gender'] == 'Male') & (data['Smoking'] == 'Yes')]

#creo fasce d'età
bins = [18, 30, 45, 60, 80, 120]
labels = ['18-30', '31-45', '46-60', '60-80', '80+']
maleSmokers['Age_Group'] = pd.cut(maleSmokers['Age'], bins=bins, labels=labels, right=False)

#conto il numero di fumatori per fascia d'età
ageGroupCounts = maleSmokers['Age_Group'].value_counts().reindex(labels)

#creo il grafico a barre
plt.figure(figsize=(10, 6))
ageGroupCounts.plot(kind='bar', color='blue', alpha=0.7, edgecolor='black')

#aggiungo titoli ed etichette
plt.title("Numero di fumatori (maschi) per fasce d'età", fontsize=16)
plt.xlabel("Fasce di età", fontsize=14)
plt.ylabel("Numero di fumatori", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

#mostro il grafico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_12328\1413604545.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maleSmokers['Age_Group'] = pd.cut(maleSmokers['Age'], bins=bins, labels=labels, right=False)
