# %% [markdown]
# # ES21
# ## Noemi Baruffolo 5^AROB
# ### pandas world weather

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./csv/GlobalWeatherRepository.csv', parse_dates = ["last_updated"])
data.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch        last_updated  temperature_celsius  \
# 0          1715849100 2024-05-16 13:15:00                 26.6
# 1          1715849100 2024-05-16 10:45:00                 19.0
# 2          1715849100 2024-05-16 09:45:00                 23.0
# 3          1715849100 2024-05-16 10:45:00                  6.3
# 4          1715849100 2024-05-16 09:45:00                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47357 entries, 0 to 47356
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       47357 non-null  object
#  1   location_name                 47357 non-null  object
#  2   latitude                      47357 non-null  float64
#  3   longitude                     47357 non-null  float64
#  4   timezone                      47357 non-null  object
#  5   last_updated_epoch            47357 non-null  int64
#  6   last_updated                  47357 non-null  object
#  7   temperature_celsius           47357 non-null  float64
#  8   temperature_fahrenheit        47357 non-null  float64
#  9   condition_text                47357 non-null  object
#  10  wind_mph                      47357 non-null  float64
#  11  wind_kph                      47357 non-null  float64
# ...

# %%
#a partire dal 1/01/1970, anno 0 degli informatici

andorra = data[data["country"]=="Andorra"]
andorra
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 3      Andorra  Andorra La Vella      42.5     1.5200  Europe/Andorra
# 198    Andorra  Andorra La Vella      42.5     1.5200  Europe/Andorra
# 393    Andorra  Andorra La Vella      42.5     1.5200  Europe/Andorra
# 586    Andorra  Andorra La Vella      42.5     1.5200  Europe/Andorra
# 779    Andorra  Andorra La Vella      42.5     1.5200  Europe/Andorra
# ...        ...               ...       ...        ...             ...
# 46385  Andorra  Andorra La Vella      42.5     1.5167  Europe/Andorra
# 46580  Andorra  Andorra La Vella      42.5     1.5167  Europe/Andorra
# 46775  Andorra  Andorra La Vella      42.5     1.5167  Europe/Andorra
# 46970  Andorra  Andorra La Vella      42.5     1.5167  Europe/Andorra
# 47165  Andorra  Andorra La Vella      42.5     1.5167  Europe/Andorra
#
#        last_updated_epoch        last_updated  temperature_celsius  \
# ...

# %%
cols = ["last_updated", "temperature_celsius", "wind_kph", "precip_mm", "humidity" , "cloud"]

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(andorra["last_updated"], andorra["temperature_celsius"])
plt.show()

# %%
fig, axs = plt.subplots(figsize = (10, 4))
for i,n in cols:
    axs[i].plot(cols[0], cols[n+1])
    axs[i].grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 fig, axs = plt.subplots(figsize = (10, 4))
# ----> 2 for i,n in cols:
#       3     axs[i].plot(cols[0], cols[n+1])
#       4     axs[i].grid()
#
# ValueError: too many values to unpack (expected 2)

# %%
#trovare la nazione mediamente più calda, più fredda, più umida, meno umida
