# %% [markdown]
# # ES01
# ## Noemi Baruffolo 5^AROB
#
# fare dizionario che salvi quante volte ogni bigramma (2 caratteri) si ripetono
# ## BONUS
# ogni N caratteri si ripete

# %%
def bigramsCounter(nome_file):
    bigrams = {}

    with open(fileName, 'r') as file:
        text = file.read()

        for i in range(0, len(text) - 2):
            bigram = text[i:i + 2]  #per estrarre il bigramma

            if bigram in bigrams:
                bigrams[bigram] += 1
            else:
                bigrams[bigram] = 1

    return bigrams

# %% [markdown]
# # BONUS

# %%
def bigramsNCounter(nome_file, n):
    bigrams = {}
    
    with open(fileName, 'r') as file:
            text = file.read()
    
            for i in range(len(text) - n):
                bigram = text[i:i + n]  #per estrarre il bigramma
    
                if bigram in bigrams:
                    bigrams[bigram] += 1
                else:
                    bigrams[bigram] = 1
    return bigrams

# %%
fileName = 'OSCAR_WILDE_Il_fantasma_di_Canterville.txt'
results = bigramsCounter(fileName)

for bigram, counter in results.items():
    print(f"{bigram}: {counter}")
# Out:
#   : 610
#  O: 68
# OS: 1
# SC: 2
# CA: 3
# AR: 5
# R : 1
#  W: 62
# WI: 1
# IL: 7
# LD: 1
# DE: 3
# E
# : 7
#
#
# : 770
#
#  : 28
#  I: 71
# Il: 65
# l : 956
#  f: 732
# fa: 370
# an: 1472
# nt: 1252
# ta: 1204
# as: 493
# sm: 96
# ma: 710
# a : 4285
#  d: 2397
# di: 1370
# i : 3056
#  C: 152
# Ca: 64
# te: 1417
# er: 2120
# rv: 141
# vi: 483
# il: 854
# ll: 1248
# le: 1013
# e
# : 339
#  e: 1284
# e : 4219
#  i: 1193
# de: 1208
# el: 1135
# li: 964
# it: 538
# tt: 842
# to: 1479
# o : 3449
#  L: 86
# Lo: 65
# or: 1275
# rd: 274
# d : 276
#  S: 160
# Sa: 14
# av: 703
#  P: 88
# Pr: 11
# ri: 1152
# im: 393
#  v: 704
# ve: 826
# rs: 285
# si: 932
# io: 862
# on: 1498
# ne: 843
# al: 962
# ia: 873
# na: 761
#  G: 52
# G.: 3
# . : 446
#  V: 103
# VA: 4
# AN: 6
# NN: 3
# NI: 6
# IC: 5
# CO: 6
# OL: 3
# LA: 3
# A.: 4
# .
# : 684
#  c: 1926
# co: 1333
# n : 1153
# is: 596
# se: 974
# eg: 387
# gn: 223
# ni: 557
#  M: 78
# MA: 4
# AZ: 3
# ZZ: 1
# ZO: 1
# ON: 9
# I.: 12
# SE: 1
# EC: 2
# ...

# %%
fileName = 'OSCAR_WILDE_Il_fantasma_di_Canterville.txt'
n = int(input("Inserisci un numero: "))
results = bigramsNCounter(fileName, n)

for bigram, counter in results.items():
    print(f"{bigram}: {counter}")
# Out:
# Inserisci un numero:  5
#      : 519
#     O: 1
#    OS: 1
#   OSC: 1
#  OSCA: 1
# OSCAR: 1
# SCAR : 1
# CAR W: 1
# AR WI: 1
# R WIL: 1
#  WILD: 1
# WILDE: 1
# ILDE
# : 1
# LDE
#
# : 1
# DE
#
#
# : 1
# E
#
#
#  : 2
#
#
#
#   : 5
#
#
#    : 15
#
#     : 23
#     I: 2
#    Il: 1
#   Il : 3
#  Il f: 4
# Il fa: 11
# l fan: 46
#  fant: 65
# fanta: 66
# antas: 67
# ntasm: 64
# tasma: 58
# asma : 41
# sma d: 10
# ma di: 20
# a di : 193
#  di C: 28
# di Ca: 15
# i Can: 21
#  Cant: 41
# Cante: 46
# anter: 50
# nterv: 48
# tervi: 47
# ervil: 46
# rvill: 46
# ville: 46
# ille
# : 4
# lle
#  : 1
# le
#   : 1
# e
#    : 2
#     e: 2
#    e : 1
#   e i: 1
#  e il: 24
# e il : 139
#  il d: 19
# il de: 7
# l del: 5
#  deli: 24
# delit: 13
# elitt: 13
# litto: 11
# itto : 16
# tto d: 34
# to di: 94
# o di : 235
#  di L: 9
# di Lo: 9
# i Lor: 3
#  Lord: 10
# Lord : 39
# ord S: 3
# rd Sa: 1
# d Sav: 1
#  Savi: 5
# Savil: 5
# avile: 5
# vile
# : 1
# ile
#
# : 1
# le
#
#
# : 1
# e
#
#
#  : 1
#     P: 1
# ...
